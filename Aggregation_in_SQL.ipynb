# %% [markdown]
# # **Aggregation in SQL**

# %% [markdown]
# **Question 1 : Count how many cities are there in each country?**
#
# **Ans-**
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 2 : Display all continents having more than 30 countries.**
#
# **Ans-**
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 3 : List regions whose total population exceeds 200 million.**
#
# **Ans-**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 4 : Find the top 5 continents by average GNP per country.**
#
# **Ans-**
#
# ![image.png](data:image/png;base64,...)
#
# ![Screenshot 2026-01-26 213859.png](data:image/png;base64,...)

# %% [markdown]
# **Question 5 : Find the total number of official languages spoken in each continent.**
#
# **Ans-**
#
#
#
#
#
# ![Screenshot 2026-01-26 220233.png](data:image/png;base64,...)![Screenshot 2026-01-26 220241.png](data:image/png;base64,...)

# %% [markdown]
# **Question 6 : Find the maximum and minimum GNP for each continent.**
#
# **Ans-**
#
# ![Screenshot 2026-01-26 220749.png](data:image/png;base64,...)![Screenshot 2026-01-26 220757.png](data:image/png;base64,...)

# %% [markdown]
# **Question 7 : Find the country with the highest average city population.**
#
# **Ans-**
#
# ![Screenshot 2026-01-26 221335.png](data:image/png;base64,...)![Screenshot 2026-01-26 221325.png](data:image/png;base64,...)

# %% [markdown]
# **Question 8 : List continents where the average city population is greater than 200,000.**
#
# **Ans-**
#
# ![Screenshot 2026-01-26 222531.png](data:image/png;base64,...)![Screenshot 2026-01-26 222512.png](data:image/png;base64,...)

# %% [markdown]
# **Question 9 : Find the total population and average life expectancy for each continent, ordered by average life
# expectancy descendin**
#
# **Ans-**
#
#
#
# ![Screenshot 2026-01-26 223541.png](data:image/png;base64,...)![Screenshot 2026-01-26 223547.png](data:image/png;base64,...)

# %% [markdown]
# **Question 10 : Find the top 3 continents with the highest average life expectancy, but only include those where
# the total population is over 200 million**
#
# **Ans-**
#
# ![Screenshot 2026-01-26 224057.png](data:image/png;base64,...)![Screenshot 2026-01-26 224114.png](data:image/png;base64,...)
